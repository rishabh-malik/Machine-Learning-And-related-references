# %% [markdown]
# # Rolling Filter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
df=pd.read_csv('all_stocks_1yr.csv',index_col='Date',parse_dates=['Date'])

# %%
df.head()
# Out:
#               Open    High     Low   Close   Volume Name
# Date
# 2016-08-12  181.47  181.47  179.90  180.27  1232856  MMM
# 2016-08-15  181.00  181.39  180.46  180.56  1268247  MMM
# 2016-08-16  180.12  180.33  179.21  179.25  1363554  MMM
# 2016-08-17  178.67  180.09  178.32  179.87  1358528  MMM
# 2016-08-18  179.70  179.70  178.58  179.18  1088677  MMM

# %%
df_aapl=df[df.Name=='AAPL']

# %%
df_aapl.head()
# Out:
#               Open    High     Low   Close    Volume  Name
# Date
# 2016-08-12  107.78  108.44  107.78  108.18  18660434  AAPL
# 2016-08-15  108.14  109.54  108.08  109.48  25868209  AAPL
# 2016-08-16  109.63  110.23  109.21  109.38  33794448  AAPL
# 2016-08-17  109.10  109.37  108.34  109.22  25355976  AAPL
# 2016-08-18  109.23  109.60  109.02  109.08  21984703  AAPL

# %%
win_length=10
win_type=[None,'boxcar','triang','blackman','hamming','nuttall']

ax=df_aapl['Open'].plot(title='Apple Open price')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
df_aapl_roll=df_aapl.rolling(win_length).mean()
df_aapl_roll.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
